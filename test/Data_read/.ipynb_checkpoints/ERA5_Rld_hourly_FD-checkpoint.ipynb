# %%
# 必要依赖：https://github.com/ecmwf/cfgrib
# conda install -c conda-forge eccodes
# conda install -c conda-forge cfgrib
import xarray
from datetime import datetime, timedelta
import numpy
import matplotlib.pyplot as plt

# %%
# Forecast albedo 0.1° x 0.1°
era5_rld_grib = '/remote_geo01/data_fd_et/ERA5_Rld/2018_01.grib'

# %%
rld_ds = xarray.load_dataset(era5_rld_grib, engine="cfgrib")

# %%
rld_ds.dims
# Out:
# Frozen(SortedKeysDict({'time': 32, 'step': 24, 'latitude': 1201, 'longitude': 951}))

# %%
numpy.array(rld_ds.isel(time=1, step=0).to_array())[:,:]/(1*60*60)
# Out:
# array([[[255.28404, 254.59175, 253.9003 , ...,       nan,       nan,
#                nan],
#         [254.89655, 254.22151, 253.55998, ...,       nan,       nan,
#                nan],
#         [254.50845, 253.85876, 253.21481, ...,       nan,       nan,
#                nan],
#         ...,
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan]]], dtype=float32)

# %%
rld_ds
# Out:
# <xarray.Dataset>
# Dimensions:     (latitude: 1201, longitude: 951, step: 24, time: 32)
# Coordinates:
#     number      int64 0
#   * time        (time) datetime64[ns] 2017-12-31 2018-01-01 ... 2018-01-31
#   * step        (step) timedelta64[ns] 01:00:00 02:00:00 ... 1 days 00:00:00
#     surface     int64 0
#   * latitude    (latitude) float64 60.0 59.9 59.8 59.7 ... -59.8 -59.9 -60.0
#   * longitude   (longitude) float64 85.0 85.1 85.2 85.3 ... 179.8 179.9 180.0
#     valid_time  (time, step) datetime64[ns] 2017-12-31T01:00:00 ... 2018-02-01
# Data variables:
#     strd        (time, step, latitude, longitude) float32 nan nan ... nan nan
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-03-19T22:16:38 GRIB to CDM+CF via cfgrib-0....

# %%
rld_ds.isel(time=0, step=0)
# Out:
# <xarray.Dataset>
# Dimensions:     (latitude: 1201, longitude: 951)
# Coordinates:
#     number      int64 0
#     time        datetime64[ns] 2017-12-31
#     step        timedelta64[ns] 01:00:00
#     surface     int64 0
#   * latitude    (latitude) float64 60.0 59.9 59.8 59.7 ... -59.8 -59.9 -60.0
#   * longitude   (longitude) float64 85.0 85.1 85.2 85.3 ... 179.8 179.9 180.0
#     valid_time  datetime64[ns] 2017-12-31T01:00:00
# Data variables:
#     strd        (latitude, longitude) float32 nan nan nan nan ... nan nan nan
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-03-19T22:16:38 GRIB to CDM+CF via cfgrib-0....

# %%
demo_rld = numpy.array(rld_ds.to_array())[0,0,23,:,:]

# %%
demo_rld_show=demo_rld/(24*60*60)
print(demo_rld_show)
plt.imshow(demo_rld_show) #！！！！！！
plt.colorbar(label='Rld')
# Out:
# [[224.54675926 223.99722222 223.44773148 ...          nan          nan
#            nan]
#  [223.99833333 223.43875    222.87458333 ...          nan          nan
#            nan]
#  [223.44916667 222.87689815 222.30263889 ...          nan          nan
#            nan]
#  ...
#  [         nan          nan          nan ...          nan          nan
#            nan]
#  [         nan          nan          nan ...          nan          nan
#            nan]
#  [         nan          nan          nan ...          nan          nan
#            nan]]

# %%
plt.figure(figsize=(10,10))
plt.imshow(rld_ds.to_array()[0,1,0, :,:]/3600, interpolation='None')
plt.colorbar(label='Rld')
plt.title('Original Rld at UTC 2018-01-01 03:00:00')
# Out:
# Text(0.5, 1.0, 'Original Rld at UTC 2018-01-01 03:00:00')

# %%
# FD extent
resolution = 0.01 # degree
lats = numpy.arange(60.-resolution/2, -60, -resolution)
lons = numpy.arange(85.+resolution/2, 180, resolution)

# %%
day_num = 1 # 1 -> 31(?)
hour_idx = 2 # 0 <=> 01:00:00

rld_dh = rld_ds.isel(time=day_num, step=hour_idx)
fd_ds = rld_dh.interp(longitude=lons, latitude=lats, method="linear", kwargs={"fill_value": "extrapolate"}) # linear
rld_v = fd_ds.to_array()[0]/3600

# %%
plt.figure(figsize=(10,10))
plt.imshow(rld_v, interpolation='None')
plt.colorbar(label='Rld')
plt.title('0.01° Rld in study extent at 2018-01-01 03:00:00')
# Out:
# Text(0.5, 1.0, '0.01° Rld in study extent at 2018-01-01 03:00:00')
