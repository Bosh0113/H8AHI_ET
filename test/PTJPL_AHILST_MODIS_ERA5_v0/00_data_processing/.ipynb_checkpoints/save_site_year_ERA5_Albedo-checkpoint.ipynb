# %%
import os
import xarray
from datetime import datetime, timedelta
import numpy

# %%
ERA5_ALBEDO_FOLDER = '/disk2/Data/ERA5_Albedo'

# %%
UTC_OFFSET = 9 # hour
time_internal = 1  # hour

tky_site_loc = (36.146, 137.423) # lat, lon
crk_site_loc = (38.201, 127.251) # lat, lon
gck_site_loc = (37.748, 127.162) # lat, lon
gdk_site_loc = (37.749, 127.149) # lat, lon
site_names = ['TKY','CRK', 'GCK', 'GDK']
site_locs = [tky_site_loc, crk_site_loc, gck_site_loc, gdk_site_loc]

# %%
def read_site_era5_albedo_month(era5_albedo_grib, lat_site, lon_site):
    albedo_ds = xarray.load_dataset(era5_albedo_grib, engine="cfgrib")
    albedo_site_ds = albedo_ds.interp(longitude=[lon_site], latitude=[lat_site], method="nearest", kwargs={"fill_value": "extrapolate"}) # linear
    
    albedo_v = numpy.array(albedo_site_ds.to_array()[0,1:,:,0,0])
    albedo_v_1d = albedo_v.flatten()
    albedo_v_1d = numpy.insert(albedo_v_1d, 0, albedo_site_ds.to_array()[0,0,23,0,0])
    albedo_v_1d = numpy.delete(albedo_v_1d, -1)
    
    return albedo_v_1d

# %%
for current_site_idx in range(len(site_names)):
    current_site_loc = site_locs[current_site_idx]

    years = ['2017', '2018', '2019']
    months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

    data_record = []
    for year_str in years:
        for month_str in months:
            year_month = year_str + '_' + month_str
            grib_filename = os.path.join(ERA5_ALBEDO_FOLDER, year_month + '.grib')
            if os.path.exists(grib_filename):
                utc_start_date = datetime.strptime(year_month + '-01T00:00:00Z', "%Y_%m-%dT%H:%M:%SZ")
                file_site_v_list = read_site_era5_albedo_month(grib_filename, current_site_loc[0], current_site_loc[1])
                current_date = utc_start_date
                for site_v in file_site_v_list:
                    local_current_date = current_date + timedelta(hours=UTC_OFFSET)
                    local_current_time = local_current_date.strftime("%Y-%m-%dT%H:%M:%SZ")
                    data_record.append([local_current_time, str(site_v)])
                    current_date = current_date + timedelta(hours=time_internal)
    albedo_site_data = numpy.array(data_record)
    
    numpy.savetxt(os.path.join(ERA5_ALBEDO_FOLDER, site_names[current_site_idx]+'_ERA5_Albedo'+'.csv'), albedo_site_data, delimiter=",", fmt='%s')
# Out:
# /home/beichen/anaconda3/envs/python36/lib/python3.6/site-packages/xarray/backends/plugins.py:61: RuntimeWarning: Engine 'cfgrib' loading failed:
# module 'cfgrib.messages' has no attribute 'DEFAULT_INDEXPATH'
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-0126297f6cdb> in <module>
#      12         if os.path.exists(grib_filename):
#      13             utc_start_date = datetime.strptime(year_month + '-01T00:00:00Z', "%Y_%m-%dT%H:%M:%SZ")
# ---> 14             file_site_v_list = read_site_era5_albedo_month(grib_filename, current_site_loc[0], current_site_loc[1])
#      15             current_date = utc_start_date
#      16             for site_v in file_site_v_list:
#
# <ipython-input-4-ac510b91bb68> in read_site_era5_albedo_month(era5_albedo_grib, lat_site, lon_site)
#       1 def read_site_era5_albedo_month(era5_albedo_grib, lat_site, lon_site):
# ----> 2     albedo_ds = xarray.load_dataset(era5_albedo_grib, engine="cfgrib")
#       3     albedo_site_ds = albedo_ds.interp(longitude=[lon_site], latitude=[lat_site], method="nearest", kwargs={"fill_value": "extrapolate"}) # linear
#       4
#       5     albedo_v = numpy.array(albedo_site_ds.to_array()[0,1:,:,0,0])
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/xarray/backends/api.py in load_dataset(filename_or_obj, **kwargs)
#     241
#     242     with open_dataset(filename_or_obj, **kwargs) as ds:
# --> 243         return ds.load()
#     244
#     245
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/xarray/core/dataset.py in load(self, **kwargs)
#     856         for k, v in self.variables.items():
#     857             if k not in lazy_data:
# --> 858                 v.load()
#     859
#     860         return self
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/xarray/core/variable.py in load(self, **kwargs)
#     452             self._data = as_compatible_data(self._data.compute(**kwargs))
#     453         elif not is_duck_array(self._data):
# --> 454             self._data = np.asarray(self._data)
#     455         return self
#     456
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     699
#     700     def __array__(self, dtype=None):
# --> 701         self._ensure_cached()
#     702         return np.asarray(self.array, dtype=dtype)
#     703
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/xarray/core/indexing.py in _ensure_cached(self)
#     696     def _ensure_cached(self):
#     697         if not isinstance(self.array, NumpyIndexingAdapter):
# --> 698             self.array = NumpyIndexingAdapter(np.asarray(self.array))
#     699
#     700     def __array__(self, dtype=None):
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     669
#     670     def __array__(self, dtype=None):
# --> 671         return np.asarray(self.array, dtype=dtype)
#     672
#     673     def __getitem__(self, key):
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     570     def __array__(self, dtype=None):
#     571         array = as_indexable(self.array)
# --> 572         return np.asarray(array[self.key], dtype=None)
#     573
#     574     def transpose(self, order):
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/xarray/backends/cfgrib_.py in __getitem__(self, key)
#      46     def __getitem__(self, key):
#      47         return indexing.explicit_indexing_adapter(
# ---> 48             key, self.shape, indexing.IndexingSupport.BASIC, self._getitem
#      49         )
#      50
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/xarray/core/indexing.py in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     861     """
#     862     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 863     result = raw_indexing_method(raw_key.tuple)
#     864     if numpy_indices.tuple:
#     865         # index the loaded np.ndarray
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/xarray/backends/cfgrib_.py in _getitem(self, key)
#      51     def _getitem(self, key):
#      52         with self.datastore.lock:
# ---> 53             return self.array[key]
#      54
#      55
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/cfgrib/dataset.py in __getitem__(self, item)
#     337                     continue
#     338                 # NOTE: fill a single field as found in the message
# --> 339                 message = self.stream.message_from_file(file, offset=offset[0])
#     340                 values = message.message_get('values', float)
#     341                 array_field.__getitem__(tuple(array_field_indexes)).flat[:] = values
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/cfgrib/messages.py in message_from_file(self, file, offset, **kwargs)
#     259
#     260     def message_from_file(self, file, offset=None, **kwargs):
# --> 261         return self.message_class.from_file(file, offset, **kwargs)
#     262
#     263     def first(self):
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/cfgrib/messages.py in from_file(cls, file, offset, **kwargs)
#      93         codes_id = None
#      94         if field_in_message == 0:
# ---> 95             codes_id = eccodes.codes_grib_new_from_file(file)
#      96         else:
#      97             # MULTI-FIELD is enabled only when accessing additional fields
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/cfgrib/bindings.py in codes_grib_new_from_file(fileobj, product_kind, context)
#     178         context = ffi.NULL
#     179     try:
# --> 180         retval = check_last(lib.codes_handle_new_from_file)(context, fileobj, product_kind)
#     181         if retval == ffi.NULL:
#     182             raise EOFError("End of file: %r" % fileobj)
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/cfgrib/bindings.py in wrapper(*args)
#     147         code = ffi.new('int *')
#     148         args += (code,)
# --> 149         retval = func(*args)
#     150         if code[0] != lib.GRIB_SUCCESS:
#     151             if code[0] in ERROR_MAP:
#
# KeyboardInterrupt:
