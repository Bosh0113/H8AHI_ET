# %%
import numpy
import os
import xarray
from datetime import datetime, timedelta
from scipy.interpolate import interp1d

# %%
WORKSPACE_FOLDER = os.path.join(os.path.abspath('..'), 'processing_record')
if not os.path.exists(WORKSPACE_FOLDER):
    os.makedirs(WORKSPACE_FOLDER)
MOD31A2_NDVI_FLODER = '/data01/people/beichen/data_fd_et/MOD31A2_NDVI'

# %%
def read_ndvi_sites(modis_ndvi_tif, site_infos):
    modis_ds = xarray.open_rasterio(modis_ndvi_tif)[0]
    
    site_v_list = []
    for site_info in site_infos:
        lat_site = site_info[1]
        lon_site = site_info[2]
        site_ds = modis_ds.interp(x=[lon_site], y=[lat_site], method="nearest", kwargs={"fill_value": "extrapolate"}) # linear
        ndvi_dn = numpy.array(site_ds.values)[0][0]
        if ndvi_dn == -3000:
            site_v_list.append(numpy.NaN)
        else:
            data_v = ndvi_dn*0.0001
            site_v_list.append(data_v)
    
    return site_v_list

# %%
site_infos = [# site, lat, lon, UTC+
    ["CLC", 44.59666667, 123.4702778, 8],
    ["JRC", 31.80683056, 119.2172639, 8],
    ["PDC", 26.6, 106.3166667, 8],
    ["PJC", 40.94138889, 121.9602778, 8],
    ["HZF", 51.78111111, 121.0177778, 8],
    ["ZAG", 32.8, 102.55, 8],
    ["DBB", 41.64397222, 110.3314722, 8],
    ["HBG", 37.61666667, 101.3166667, 8],
    ["MPM", 22.4982, 114.0292, 8],
    ["BBY", 43.323, 141.8107, 9],
    ["TKY", 36.14616667, 137.4231111, 9],
    ["CRK", 38.20138889, 127.2505556, 9],
    ["GCK", 37.74833333, 127.1622222, 9],
    ["GDK", 37.74888889, 127.1491667, 9],
    ["SIP", 0.395204167, 102.7645506, 7],
    ["SDP", 0.699491389, 102.793305, 7],
    ["ASM", -22.2828, 133.2493, 9],
    ["CPW", -33.6152, 150.7236, 11],
    ["WAR", -43.095, 146.6545, 11]
]

# %%
# 1. record full day from 20180101 to 20191231 in daily
# 2. extend daily into every 10-min 
# 3. save site data

time_internal = 10 # min
START_TIME = '2018-01-01T00:00:00Z' # local time
END_TIME = '2019-12-31T23:59:59Z'

years = ['2018', '2019']
year_days = [(3-len(str(day_n)))*'0' + str(day_n) for day_n in numpy.arange(1, 366, 16)]

data_record = [] # daily
for site_idx in range(len(site_infos)):
    data_record.append([])

for year_str in years:
    for day_idx in range(len(year_days)):
        day_str = year_days[day_idx]
        ndvi_filename = os.path.join(MOD31A2_NDVI_FLODER, 'MOD13A2.061__1_km_16_days_NDVI_doy' + year_str + day_str + '_aid0001.tif')

        day_site_list = read_ndvi_sites(ndvi_filename, site_infos)
        
        for site_idx in range(len(site_infos)):
            record_item = data_record[site_idx]
            day_site_v = day_site_list[site_idx]
            record_item.append(day_site_v)
            data_record[site_idx] = record_item
# Out:
# /tmp/ipykernel_1293628/1481736720.py:2: DeprecationWarning: open_rasterio is Deprecated in favor of rioxarray. For information about transitioning, see: https://corteva.github.io/rioxarray/stable/getting_started/getting_started.html
#   modis_ds = xarray.open_rasterio(modis_ndvi_tif)[0]
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# 2083.0
# 2687.0
# 6143.0
# 1462.0
# 5668.0
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# 1726.0
# 1296.0
# 2184.0
# 7228.0
# -39.0
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# 1731.0
# 1817.0
# 4667.0
# 3830.0
# 4121.0
# 5529.0
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /tmp/ipykernel_1293628/1481736720.py:2: DeprecationWarning: open_rasterio is Deprecated in favor of rioxarray. For information about transitioning, see: https://corteva.github.io/rioxarray/stable/getting_started/getting_started.html
#   modis_ds = xarray.open_rasterio(modis_ndvi_tif)[0]
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# 2871.0
# 5474.0
# 8025.0
# 392.0
# 107.0
# 192.0
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# 1652.0
# 3154.0
# 1913.0
# 1225.0
# 1873.0
# 6384.0
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# 127.0
# 2902.0
# 1957.0
# 3198.0
# 2861.0
# 5453.0
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# 5378.0
# 2847.0
# 5522.0
# 8326.0
# 1959.0
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /tmp/ipykernel_1293628/1481736720.py:2: DeprecationWarning: open_rasterio is Deprecated in favor of rioxarray. For information about transitioning, see: https://corteva.github.io/rioxarray/stable/getting_started/getting_started.html
#   modis_ds = xarray.open_rasterio(modis_ndvi_tif)[0]
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
# ...
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# 6007.0
# 9300.0
# 7826.0
# 8940.0
# 8646.0
# 8305.0
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# 8520.0
# 2482.0
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:562: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imin = index.get_loc(minval, method="nearest")
# /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/missing.py:563: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   imax = index.get_loc(maxval, method="nearest")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 16>()
#      18 day_str = year_days[day_idx]
#      19 ndvi_filename = os.path.join(MOD31A2_NDVI_FLODER, 'MOD13A2.061__1_km_16_days_NDVI_doy' + year_str + day_str + '_aid0001.tif')
# ---> 21 day_site_list = read_ndvi_sites(ndvi_filename, site_infos)
#      23 for site_idx in range(len(site_infos)):
#      24     record_item = data_record[site_idx]
#
# Input In [3], in read_ndvi_sites(modis_ndvi_tif, site_infos)
#       6 lat_site = site_info[1]
#       7 lon_site = site_info[2]
# ----> 8 site_ds = modis_ds.interp(x=[lon_site], y=[lat_site], method="nearest", kwargs={"fill_value": "extrapolate"}) # linear
#       9 ndvi_dn = numpy.array(site_ds.values)[0][0]
#      10 if ndvi_dn == -3000:
#
# File /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/dataarray.py:1742, in DataArray.interp(self, coords, method, assume_sorted, kwargs, **coords_kwargs)
#    1737 if self.dtype.kind not in "uifc":
#    1738     raise TypeError(
#    1739         "interp only works for a numeric type array. "
#    1740         "Given {}.".format(self.dtype)
#    1741     )
# -> 1742 ds = self._to_temp_dataset().interp(
#    1743     coords,
#    1744     method=method,
#    1745     kwargs=kwargs,
#    1746     assume_sorted=assume_sorted,
#    1747     **coords_kwargs,
#    1748 )
#    1749 return self._from_temp_dataset(ds)
#
# File /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/dataset.py:3183, in Dataset.interp(self, coords, method, assume_sorted, kwargs, method_non_numeric, **coords_kwargs)
#    3180 if name in indexers:
#    3181     continue
# -> 3183 if is_duck_dask_array(var.data):
#    3184     use_indexers = dask_indexers
#    3185 else:
#
# File /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/variable.py:346, in Variable.data(self)
#     344     return self._data
#     345 else:
# --> 346     return self.values
#
# File /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/variable.py:519, in Variable.values(self)
#     516 @property
#     517 def values(self):
#     518     """The variable's data as a numpy.ndarray"""
# --> 519     return _as_array_or_item(self._data)
#
# File /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/variable.py:259, in _as_array_or_item(data)
#     245 def _as_array_or_item(data):
#     246     """Return the given values as a numpy array, or as an individual item if
#     247     it's a 0d datetime64 or timedelta64 array.
#     248
#    (...)
#     257     TODO: remove this (replace with np.asarray) once these issues are fixed
#     258     """
# --> 259     data = np.asarray(data)
#     260     if data.ndim == 0:
#     261         if data.dtype.kind == "M":
#
# File /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:551, in MemoryCachedArray.__array__(self, dtype)
#     550 def __array__(self, dtype=None):
# --> 551     self._ensure_cached()
#     552     return np.asarray(self.array, dtype=dtype)
#
# File /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:548, in MemoryCachedArray._ensure_cached(self)
#     546 def _ensure_cached(self):
#     547     if not isinstance(self.array, NumpyIndexingAdapter):
# --> 548         self.array = NumpyIndexingAdapter(np.asarray(self.array))
#
# File /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:521, in CopyOnWriteArray.__array__(self, dtype)
#     520 def __array__(self, dtype=None):
# --> 521     return np.asarray(self.array, dtype=dtype)
#
# File /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:422, in LazilyIndexedArray.__array__(self, dtype)
#     420 def __array__(self, dtype=None):
#     421     array = as_indexable(self.array)
# --> 422     return np.asarray(array[self.key], dtype=None)
#
# File /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/backends/rasterio_.py:130, in RasterioArrayWrapper.__getitem__(self, key)
#     129 def __getitem__(self, key):
# --> 130     return indexing.explicit_indexing_adapter(
#     131         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     132     )
#
# File /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:711, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     689 """Support explicit indexing by delegating to a raw indexing method.
#     690
#     691 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#     708 Indexing result, in the form of a duck numpy-array.
#     709 """
#     710 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 711 result = raw_indexing_method(raw_key.tuple)
#     712 if numpy_indices.tuple:
#     713     # index the loaded np.ndarray
#     714     result = NumpyIndexingAdapter(np.asarray(result))[numpy_indices]
#
# File /data01/people/beichen/anaconda3/lib/python3.9/site-packages/xarray/backends/rasterio_.py:123, in RasterioArrayWrapper._getitem(self, key)
#     121         if self.vrt_params is not None:
#     122             riods = WarpedVRT(riods, **self.vrt_params)
# --> 123         out = riods.read(band_key, window=window)
#     125 if squeeze_axis:
#     126     out = np.squeeze(out, axis=squeeze_axis)
#
# KeyboardInterrupt:

# %%
data_first_date = datetime.strptime(START_TIME, "%Y-%m-%dT%H:%M:%SZ")
for site_idx in range(len(site_infos)):
    site_v_d = numpy.array(data_record[site_idx])
    # filldata
    site_v_d = site_v_d
    valid_indices = numpy.where(~numpy.isnan(site_v_d))[0]
    if len(valid_indices)>1:
        valid_values = site_v_d[valid_indices]
        interpolator = interp1d(valid_indices, valid_values, kind='nearest', fill_value='extrapolate')
        ndvi_16day_imp = interpolator(numpy.arange(len(site_v_d)))
    else:
        print('all are nan.')
        ndvi_16day_imp = site_v_d[:]
    # 16daily to 10-min
    site_v_10min = numpy.repeat(ndvi_16day_imp, 16*6*24)
    site_record_10min = []
    current_date = data_first_date
    for site_v in site_v_10min:
        current_day_time = current_date.strftime("%Y-%m-%dT%H:%M:%SZ")
        site_record_10min.append([current_day_time, str(site_v)])
        current_date = current_date + timedelta(minutes=time_internal)
    ndvi_record = numpy.array(site_record_10min)
    save_filename = os.path.join(WORKSPACE_FOLDER, site_infos[site_idx][0]+'_MOD13A2_NDVI'+'.csv')
    print(save_filename)
    numpy.savetxt(save_filename, ndvi_record, delimiter=",", fmt='%s')
